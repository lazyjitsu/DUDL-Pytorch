# %% [markdown]
# <font color="teal" size=9>Function error checking and handling</font>

# %%
def funfun(x,y):
    # check that inputs are numeric
    #if not isinstance(x,int):
    # allow for both ints and floats
    #if not isinstance(x,int) or not isinstance(x,float):
    if not isinstance(x,(int,float)):
       # raise Exception('Input x must be a number!')

        # check if x can be converted into a number using isnumeric()
        if isinstance(x,str) and x.isnumeric():
            x = float(x)
            print('Note: converted x to a float ',x)
        else:
            raise Exception('Input x must be anumber!')
    z = x*y
    return z
    print(x,y)
# funfun(4.0,3)
funfun(3.3,4)
funfun('2',1)
# Out:
# Note: converted x to a float  2.0
# 2.0

# %%
# Try and Except
def morefun(x,y):
    z = 0
    try:
        z = x**y
    except:
        print("cant do it bro")
    
    return z

morefun(3,"ald")
morefun(2,4)
# Out:
# cant do it bro
# 16
