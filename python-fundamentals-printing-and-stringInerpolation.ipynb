# %% [markdown]
# <font color="teal" size=9>Text and Plots</font>

# %%
## String Interpolation
num = 11.7
sng = 'cellar doors'
# alittle long and tedious
print('I would like to have ' + str(num) + ' ' + sng + '.')
# more compact/readable
print('I would like to have %g %s ' %(num,sng))
print('I would like to have %f %s ' %(num,sng))
print('I would like to have %.3f %s ' %(num,sng))
print('I would like to have %15.3f %s ' %(num,sng)) # 15 spaces before float#
# Out:
# I would like to have 11.7 cellar doors.
# I would like to have 11.7 cellar doors
# I would like to have 11.700000 cellar doors
# I would like to have 11.700 cellar doors
# I would like to have          11.700 cellar doors

# %%
# f-strings
print(f'I would like to have {num:.2f} {sng}')
# similar
print(f'another way {num:.2f} {sng}'.format(num=num,sng=sng))
#same
print(f'another way {num:.2f} {sng}'.format(n=num,s=sng))
# Out:
# I would like to have 11.70 cellar doors
# another way 11.70 cellar doors
# another way 11.70 cellar doors

# %%
# Ex: print out ea. letter of the alpha with its ordinal position

import string
letters = string.ascii_lowercase

for i in (range(len(letters))):

    print(f'{letters[i]} is the {i+1}th letter of the alphabet')
# Out:
# a is the 1th letter of the alphabet
# b is the 2th letter of the alphabet
# c is the 3th letter of the alphabet
# d is the 4th letter of the alphabet
# e is the 5th letter of the alphabet
# f is the 6th letter of the alphabet
# g is the 7th letter of the alphabet
# h is the 8th letter of the alphabet
# i is the 9th letter of the alphabet
# j is the 10th letter of the alphabet
# k is the 11th letter of the alphabet
# l is the 12th letter of the alphabet
# m is the 13th letter of the alphabet
# n is the 14th letter of the alphabet
# o is the 15th letter of the alphabet
# p is the 16th letter of the alphabet
# q is the 17th letter of the alphabet
# r is the 18th letter of the alphabet
# s is the 19th letter of the alphabet
# t is the 20th letter of the alphabet
# u is the 21th letter of the alphabet
# v is the 22th letter of the alphabet
# w is the 23th letter of the alphabet
# x is the 24th letter of the alphabet
# y is the 25th letter of the alphabet
# ...

# %%
## Plotting dots and lines
import matplotlib.pyplot as plt 

#plt.plot(3,4) # this plots but can't see cause it's just one point!
# so to fix that we'll put an 'o' for a dot. Other markes include: 's' for square, 'p' pentagram, '^' for a triangle and others 
#plt.plot(3,4,'o')
# to make the dot green
plt.plot(3,4,'go')
# plot another point in the same chart
plt.plot(2,4.2,'b^')
## if we want them to be on diff charts

# %%
# seperate charts
plt.plot(3,4,'^r',label='red triangle')
plt.legend()
plt.show() # build chart based on prev line
plt.plot(1,10,'ro',label='red dot')
plt.legend()
plt.show()

# %%
# seperate charts
plt.plot(3,4,'^r')
plt.plot(1,10,'bo')
plt.legend(['red triangle','blue dot'])

plt.show()

# %%
# draw a line
# x = (0,1)
# y = (0,2)
x = [0,1]
y = [0,2]
plt.plot(x,y,'m') #magenta color line

# %%
# draw a line
# x = (0,1)
# y = (0,2)
x = [0,1,3]
y = [0,2,-1]
plt.plot(x,y,'m') #magenta color line

# %%
x = [0,1,3]
y = [0,2,-1]
plt.plot(x,y,'ms--') #magenta color line w/squares
plt.plot(x,y,'ms:') #magenta color line w/squares, dotted lines

# %%
import numpy as np
# 101 increments between 0 and pi
x = np.linspace(0,3*np.pi,101)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
# Ex: Favorite letter on a chart
plt.plot([0,1],[0,1],'m',linewidth=5)
plt.plot([0,1],[1,0],'m')
plt.axis('square')
plt.show()

# %% [markdown]
# <font color="teal" size=9>Subplot Geometry</font>

# %%
import matplotlib.pyplot as plt 
import numpy as np

plt.subplot(1,2,1)
plt.plot(np.random.randn(5))

plt.subplot(1,2,2)
plt.plot(np.random.randn(5))

plt.show()

# %%
# subplots is better than subplot

fig,ax = plt.subplots(1,2)
x = np.arange(10)
ax[0].plot(x,x**2,'b')
ax[0].plot(x,x,'r')

ax[1].plot(x,np.sqrt(x),'r')
plt.show()

# %%
# we can use figsize w/tuples (width,height)

fig,ax = plt.subplots(2,2,figsize=(15,3))
# ax.shape
ax[0,0].plot(np.random.randn(4,4))
ax[0,1].plot(np.random.randn(4,4))
ax[1,0].plot(np.random.randn(4,4))
ax[1,1].plot(np.random.randn(4,4))
plt.tight_layout()
plt.show()

# %%
# flatten demo
#M = np.random.randint(10,size=(4,4))
#M,M.flatten()
#
#fig,ax = plt.subplots(3,3,figsize=(7,7))
#
#for i in ax.flatten(): #every i is a subplot
#    # print("I " + str(i))
#    i.plot(np.random.randn(3,9))
#plt.show()

# %%
# Making graphs look nicer
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3,3,101)
plt.plot(x,x,label='y=x')
plt.plot(x,x**2,label='y=x**2')
plt.plot(x,x**3,label='y=x**3')
plt.legend()
plt.xlabel("X",fontsize=12)
plt.ylabel("Y=f(x)")

plt.title("A coool Plot")
# plt.xlim([-3,3]) which is hardcoded for -3 and 3 lets try soft coding
plt.xlim(x[0],x[-1])
plt.ylim(-10,10)
# plt.axis('square')
# Better to use gca() - get current axis--because square may not work/look correct--sets the aspect ratio--
# IOW: the size/distance of the ticks on x and y axis
# use 1 if you want the distance of the ticks to be equal on the x and y axis. 'auto' is the same as not having it set
plt.gca().set_aspect(.3) 
plt.show()

# %%
# Subplots ; Better than subplot
fig,ax = plt.subplots(2)

x = np.linspace(-3,3,101)
ax[0].plot(x,x,label='y=x')
ax[0].plot(x,x**2,label='y=x**2')
ax[0].plot(x,x**3,label='y=x**3')
ax[0].legend()
ax[0].set_xlabel("X",fontsize=12)
ax[0].set_ylabel("Y=f(x)")
ax[0].set_xlim([x[0],x[-1]])
ax[0].set_ylim([-10,10])

ax[0].set_title("A cool Plot 0")

ax[1].plot(x,x,label='y=x')
ax[1].plot(x,x**2,label='y=x**2')
ax[1].plot(x,x**3,label='y=x**3')
ax[1].legend()
ax[1].set_xlabel("X",fontsize=12)
ax[1].set_ylabel("Y=f(x)")
ax[1].set_title("A cool Plot 1")
# Out:
# Text(0.5, 1.0, 'A cool Plot 1')

# %%
fig,ax = plt.subplots(2,3,figsize=(15,7))

x = np.linspace(-3,3,101)
ax[0,0].plot(x,x,label='y=x')
ax[0,0].plot(x,x**2,label='y=x**2')
ax[0,0].plot(x,x**3,label='y=x**3')
ax[0,0].legend()
ax[0,0].set_xlabel("X",fontsize=12)
ax[0,0].set_ylabel("Y=f(x)")
ax[0,0].set_xlim([x[0],x[-1]])
ax[0,0].set_ylim([-10,10])

ax[0,1].plot(x,x,label='y=x')
ax[0,1].plot(x,x**2,label='y=x**2')
ax[0,1].plot(x,x**3,label='y=x**3')
ax[0,1].legend()
ax[0,1].set_xlabel("X",fontsize=12)
ax[0,1].set_ylabel("Y=f(x)")
ax[0,1].set_xlim([x[0],x[-1]])
ax[0,1].set_ylim([-10,10])

# make sure the subplots are not laying on top of ea. other
plt.tight_layout() 
plt.show()

# %%
# Ex: make a cool charrt with ascending lines. 
import numpy as np
fig,ax = plt.subplots()
x = np.linspace(0,10,100)

for i in np.linspace(0,1,50):
    # print(i)
    #              color=r,g,b 
    ax.plot(x,x**i,color=[i/2,0,i])
plt.show()

# %% [markdown]
# <font color="teal" size=9>Seaborn</font>

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 

import seaborn as sns

n = 200

D = np.zeros((n,2))
# the first col will be linearly spaced numbers from 0 to 10 in N steps (i.e 200 steps) + some random noise
D[:,0] = np.linspace(0,10,n) + np.random.randn(n)

D[:,1] = D[:,0]**2 + np.random.randn(n)*10
 #  a hack cause sns don't work same as Udemy's version
sns.jointplot(x=D[:,0],y=D[:,1])
# the way plt would plot it
#plt.plot(D[:0,],D[:,1]) 
plt.show()

# %%
df = pd.DataFrame(data=D,columns=['var1','var2'])
df
# sns.jointplot(x=df.columns[0],y=df.columns[1],data=df)
# recall a 'kde' stands for kernel densitiy estimator and is used to estimate the probability density
sns.jointplot(x=df.columns[0],y=df.columns[1],data=df,kind='kde',color='purple')

plt.show()

# %%
# Scatter Plot
x = np.linspace(-1,1,n)
# nothing special about the 3 below fcns. It just looks cool/visual for the demo per Udemy
y1 = x**2
y2 = np.sin(3*x)
y3 = np.exp(-10*x**2)

# sns.scatterplot(x=y1,y=y2,hue=y3,legend=False)
sns.scatterplot(x=y1,y=y2,hue=y3,legend=False,palette='Spectral')
# Out:
# <Axes: >

# %%
sns.regplot(data=df,x=df.columns[0],y=df.columns[1],color="green")
plt.title(f'Regression of {df.columns[0]} on {df.columns[1]}')
# Out:
# Text(0.5, 1.0, 'Regression of var1 on var2')

# %% [markdown]
# <font color="teal" size=11>Visualizing Matricies</font>
#
# Now how do we visualize a matrix?

# %%
m = 3
n = 5

M = np.random.randint(10,size=(m,n))
print(M), print(' ')
plt.plot(M)
# note the blue line looks like the first col: 5,3,9 and yellow the second: 8,3,3
# so u will see ea. line corresponds to a column. It's not a great visualization as we will see
# Out:
# [[5 8 8 1 0]
#  [3 3 0 3 4]
#  [9 3 2 8 0]]
# ...

# %%
plt.imshow(M)
plt.colorbar()
# plt.text(0,1,'hii')
# The X axis in an image corresponds to the columns in each row,
# whereas the Y axis actually corresponds to the rows,not the columns. So we swap i & j (see below)
from imageio import imread
for i in range(m):
    for j in range(n):
        plt.text(j,i,str(M[i,j]),fontsize=20,
                 horizontalalignment='center')

print(M)
# Out:
# [[5 8 8 1 0]
#  [3 3 0 3 4]
#  [9 3 2 8 0]]

# %%
img = imread('https://upload.wikimedia.org/wikipedia/commons/2/28/JPG_Test.jpg')
# img
# img.shape # it's 3d so that means its NOT grayscale but color
plt.title('random pic')
for i in range(m):
    for j in range(n):
        plt.text(j,i,str(M[i,j]),fontsize=20,
                 horizontalalignment='center')

# print(M)
plt.imshow(img)
plt.colorbar()
plt.show()
# Out:
# C:\Users\mpere\AppData\Local\Temp\ipykernel_25136\544393401.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imread('https://upload.wikimedia.org/wikipedia/commons/2/28/JPG_Test.jpg')

# %%
# img.shape
plt.hist(img.flatten(),bins=50)
# x axis is the color value, y-axis is the count
# Out:
# (array([ 2491205.,   686453.,   364576.,    83340.,   431397.,   118718.,
#            90817.,  1823862.,   232110.,   250581.,   362753.,   352811.,
#           592877.,   270253.,   322408.,   336317.,   295962.,   130368.,
#          1470546.,   169471.,  3603295.,   413833.,   320380.,    67034.,
#            84126.,   119640.,   151277.,   166988.,   422349.,   493418.,
#           111844.,   104955.,    79280.,   301494.,   454920.,   585634.,
#          1694208.,   283006.,   422852.,  2662786.,   950903.,    86911.,
#            83733.,    98375.,   304493.,   322659.,   184923.,   381178.,
#           167212., 10690669.]),
#  array([  0. ,   5.1,  10.2,  15.3,  20.4,  25.5,  30.6,  35.7,  40.8,
#          45.9,  51. ,  56.1,  61.2,  66.3,  71.4,  76.5,  81.6,  86.7,
#          91.8,  96.9, 102. , 107.1, 112.2, 117.3, 122.4, 127.5, 132.6,
#         137.7, 142.8, 147.9, 153. , 158.1, 163.2, 168.3, 173.4, 178.5,
# ...

# %%
# this means all colors below 50 will have same color, all above 200 will have same color
plt.imshow(img,cmap="grey",vmin=1000,vmax=1100)
plt.show()
# not setting to grayscale..figure this out later

# %% [markdown]
# Ex: Visualize the Hilbert matrix using seaborn (heatmap)
# $H_{i}{j} = \frac{1}{i + j} - 1 $

# %%
import seaborn as sns
n = 10
H = np.zeros((n,n))

for i in range(n):
    for j in range(n):
        # H[i,j] = 1 /(i+j -1 )  # generates a div by zero error. solve by starting at 1
        H[i,j] = 1 / ((i+1) + (j+1) - 1)

sns.heatmap(H,vmax=.4) #.4 is just an arbirtary # we chose
plt.show()

# %%
# Export plots in low and high resolution
import numpy as np
import matplotlib.pyplot as plt

from IPython import display
# display.set_matplotlib_formats('svg')

x = np.linspace(.5,5,10)
y1 = np.log(x)
y2 = 2-np.sqrt(x)

plt.plot(x,y1,'bo-',label='log')
plt.plot(x,y2,'rs-',label='sqrt')

plt.legend()

plt.show()

# %%
# Better resolution
display.set_matplotlib_formats('svg')

x = np.linspace(.5,5,10)
y1 = np.log(x)
y2 = 2-np.sqrt(x)

plt.plot(x,y1,'bo-',label='log')
plt.plot(x,y2,'rs-',label='sqrt')

plt.legend()

plt.savefig('test.png')
# files.download('test.png') # if u don't see it..i got it in my IDE (IOW vcode did it for me)
plt.show()
# Out:
# C:\Users\mpere\AppData\Local\Temp\ipykernel_23152\765853812.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')
